# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
batch_sizes = [1, 2, 3, 5, 8, 10]
names = ['Vishesh', 'Shrestha', 'Biswajeet', 'Priyanka', 'Poonam', 'Adhiraaj', 'Yash', 'Sachin', 'Vinayak', 'Kranti', 'Sai']
thresholds = [0.5, 0.7, 0.9, 1.0]

# Mapping of names to discrete values
name_to_idx = {name: idx for idx, name in enumerate(names)}

# Recommended nodes data
recommendations = {
    0.5: {
        1: ['Yash', 'Biswajeet', 'Sai'],
        2: ['Biswajeet', 'Adhiraaj', 'Vinayak'],
        3: ['Shrestha', 'Vinayak', 'Biswajeet'],
        5: ['Poonam', 'Shrestha', 'Biswajeet'],
        8: ['Sai', 'Vinayak', 'Biswajeet'],
        10: ['Vinayak', 'Priyanka', 'Sai']
    },
    0.7: {
        1: ['Poonam', 'Yash', 'Vinayak'],
        2: ['Adhiraaj', 'Biswajeet', 'Shrestha'],
        3: ['Priyanka', 'Adhiraaj', 'Shrestha'],
        5: ['Adhiraaj', 'Priyanka', 'Biswajeet'],
        8: ['Biswajeet', 'Priyanka', 'Adhiraaj'],
        10: ['Sai', 'Vinayak', 'Biswajeet']
    },
    0.9: {
        1: ['Poonam', 'Shrestha', 'Adhiraaj'],
        2: ['Sai', 'Sachin', 'Shrestha'],
        3: ['Priyanka', 'Sachin', 'Biswajeet'],
        5: ['Poonam', 'Vinayak', 'Sachin'],
        8: ['Sai', 'Shrestha', 'Priyanka'],
        10: ['Shrestha', 'Priyanka', 'Adhiraaj']
    },
    1.0: {
        1: ['Yash', 'Biswajeet'],
        2: ['Shrestha', 'Adhiraaj', 'Vinayak'],
        3: ['Biswajeet', 'Poonam', 'Vinayak'],
        5: ['Priyanka', 'Biswajeet', 'Poonam'],
        8: ['Priyanka', 'Sai', 'Yash'],
        10: ['Yash', 'Vinayak']
    }
}

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

colors = {0.5: 'red', 0.7: 'blue', 0.9: 'green', 1.0: 'purple'}
markers = {0.5: 'o', 0.7: 's', 0.9: 'D', 1.0: 'x'}

for thr in thresholds:
    for batch_size in batch_sizes:
        recommended_nodes = recommendations[thr][batch_size]
        y_value = batch_size
        x_values = [name_to_idx[name] for name in recommended_nodes]
        ax.scatter(x_values, [y_value] * len(x_values), c=colors[thr], label=f'Threshold {thr}' if batch_size == 1 else "", marker=markers[thr], s=100)

# Customizing the plot
ax.set_title('Recommended Nodes for Vishesh')
ax.set_xlabel('Names')
ax.set_ylabel('Batch Size')
ax.set_xticks(range(len(names)))
ax.set_xticklabels(names, rotation=90)
ax.set_yticks(batch_sizes)
ax.legend(title='Thresholds')

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data organized similar to 'Vishesh'
individuals = {
    'Shrestha': {
        0.5: {
            1: ['Vishesh'],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: ['Vishesh'],
            8: ['Vishesh'],
            10: ['Vishesh']
        },
        0.7: {
            1: ['Vishesh'],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: ['Vishesh'],
            8: ['Vishesh'],
            10: ['Vishesh']
        },
        0.9: {
            1: ['Vishesh'],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: ['Vishesh'],
            8: ['Vishesh'],
            10: ['Vishesh']
        },
        1.0: {
            1: [],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: [],
            8: ['Vishesh'],
            10: ['Vishesh']
        }
    },
    'Vishesh':{ 
    0.5 :  {
    1 : ['biswajeet', 'vinayak', 'yash'],
    2 : ['shrestha', 'poonam', 'sachin'],
    3 : ['adhiraaj', 'shrestha', 'priyanka'],
    5 : ['biswajeet', 'shrestha', 'sai'],
    8 : ['shrestha', 'priyanka', 'vinayak'],
    10 : ['sachin', 'biswajeet', 'adhiraaj']},
    0.7 : {
    1 : ['shrestha', 'biswajeet', 'poonam'],
    2 : ['shrestha', 'yash', 'adhiraaj'],
    3 : ['priyanka', 'shrestha', 'poonam'],
    5 : ['shrestha', 'sai', 'biswajeet'],
    8 : ['shrestha', 'adhiraaj', 'priyanka'],
    10 : ['poonam', 'vinayak', 'sai']},
    0.9 : {
    1 : ['priyanka', 'biswajeet', 'sai'],
    2 : ['poonam', 'shrestha', 'vinayak'],
    3 : ['vinayak', 'sachin', 'priyanka'],
    8 : ['shrestha', 'priyanka', 'vinayak'],
    10 : ['sai', 'yash', 'adhiraaj']},
    1.0 : {
    1 : ['adhiraaj', 'poonam', 'vinayak'],
    2 : ['adhiraaj', 'shrestha', 'biswajeet'],
    3 : ['biswajeet', 'yash', 'sachin'],
    5 : ['poonam', 'yash', 'sai'],
    8 : ['sai', 'adhiraaj', 'shrestha'],
    10 : ['shrestha', 'adhiraaj', 'yash']
        }
    },
    'Biswajeet': {
        0.5: {
            1: ['Kranti', 'Vinayak', 'Sachin'],
            2: ['Kranti', 'Sachin', 'Yash'],
            3: ['Sai', 'Adhiraaj', 'Vishesh'],
            5: ['Priyanka', 'Poonam', 'Kranti'],
            8: ['Sachin', 'Adhiraaj', 'Vinayak'],
            10: ['Poonam', 'Priyanka', 'Sachin']
        },
        0.7: {
            1: ['Yash', 'Vishesh', 'Sai'],
            2: ['Adhiraaj', 'Sachin', 'Yash'],
            3: ['Sai', 'Vishesh', 'Adhiraaj'],
            5: ['Sai', 'Priyanka', 'Kranti'],
            8: ['Vishesh', 'Sachin', 'Sai'],
            10: ['Sai', 'Poonam', 'Priyanka']
        },
        0.9: {
            1: ['Sachin', 'Vinayak', 'Adhiraaj'],
            2: ['Sai', 'Vinayak', 'Poonam'],
            3: ['Sai', 'Priyanka', 'Poonam'],
            5: ['Sai', 'Adhiraaj', 'Sachin'],
            8: ['Sachin', 'Sai', 'Kranti'],
            10: ['Kranti', 'Vinayak', 'Yash']
        },
        1.0: {
            1: ['Sai', 'Sachin', 'Yash'],
            2: ['Kranti', 'Sachin', 'Adhiraaj'],
            3: ['Poonam', 'Vinayak', 'Priyanka'],
            5: ['Sai', 'Yash', 'Priyanka'],
            8: ['Sai', 'Vinayak', 'Vishesh'],
            10: ['Vinayak', 'Sai', 'Sachin']
        }
    },
    'Priyanka': {
        0.5: {
            1: ['Sachin', 'Vishesh', 'Yash'],
            2: ['Adhiraaj', 'Biswajeet', 'Yash'],
            3: ['Adhiraaj', 'Biswajeet', 'Yash'],
            5: ['Sachin', 'Vishesh', 'Biswajeet'],
            8: ['Poonam', 'Biswajeet', 'Adhiraaj'],
            10: ['Sachin', 'Adhiraaj', 'Biswajeet']
        },
        0.7: {
            1: ['Adhiraaj', 'Yash', 'Vishesh'],
            2: ['Sachin', 'Yash', 'Biswajeet'],
            3: ['Vishesh', 'Biswajeet', 'Sachin'],
            5: ['Vishesh', 'Biswajeet', 'Sachin'],
            8: ['Yash', 'Biswajeet', 'Poonam'],
            10: ['Adhiraaj', 'Vishesh', 'Biswajeet']
        },
        0.9: {
            1: ['Yash', 'Sachin', 'Poonam'],
            2: ['Yash', 'Sachin', 'Adhiraaj'],
            3: ['Adhiraaj', 'Sachin', 'Yash'],
            5: ['Biswajeet', 'Poonam', 'Yash'],
            8: ['Adhiraaj', 'Yash', 'Poonam'],
            10: ['Biswajeet', 'Sachin', 'Adhiraaj']
        },
        1.0: {
            1: ['Vishesh', 'Sachin', 'Adhiraaj'],
            2: ['Biswajeet', 'Vishesh', 'Sachin'],
            3: ['Biswajeet', 'Yash', 'Sachin'],
            5: ['Sachin', 'Poonam', 'Adhiraaj'],
            8: ['Yash', 'Poonam', 'Sachin'],
            10: ['Biswajeet', 'Poonam', 'Yash']
        }
    },
    'Poonam': {
        0.5: {
            1: ['Adhiraaj', 'Yash', 'Biswajeet'],
            2: ['Adhiraaj', 'Sachin', 'Biswajeet'],
            3: ['Adhiraaj', 'Priyanka', 'Sachin'],
            5: ['Vishesh', 'Yash', 'Priyanka'],
            8: ['Adhiraaj', 'Priyanka', 'Vishesh'],
            10: ['Vishesh', 'Biswajeet', 'Priyanka']
        },
        0.7: {
            1: ['Adhiraaj', 'Sachin', 'Biswajeet'],
            2: ['Vishesh', 'Biswajeet', 'Adhiraaj'],
            3: ['Priyanka', 'Vishesh', 'Yash'],
            5: ['Priyanka', 'Sachin', 'Yash'],
            8: ['Priyanka', 'Biswajeet', 'Sachin'],
            10: ['Adhiraaj', 'Priyanka', 'Sachin']
        },
        0.9: {
            1: ['Sachin', 'Vishesh', 'Priyanka'],
            2: ['Vishesh', 'Sachin', 'Priyanka'],
            3: ['Vishesh', 'Biswajeet', 'Yash'],
            5: ['Vishesh', 'Yash', 'Adhiraaj'],
            8: ['Adhiraaj', 'Sachin', 'Priyanka'],
            10: ['Priyanka', 'Biswajeet', 'Vishesh']
        },
        1.0: {
            1: ['Vishesh', 'Biswajeet', 'Priyanka'],
            2: ['Yash', 'Priyanka', 'Biswajeet'],
            3: ['Biswajeet', 'Vishesh', 'Priyanka'],
            5: ['Biswajeet', 'Adhiraaj', 'Sachin'],
            8: ['Vishesh', 'Yash', 'Biswajeet'],
            10: ['Adhiraaj', 'Biswajeet']
        }
    },
    'Adhiraaj': {
    0.5: {
        1: ['Vishesh', 'Biswajeet', 'Kranti'],
        2: ['Vishesh', 'Biswajeet', 'Kranti'],
        3: ['Vishesh', 'Biswajeet', 'Kranti'],
        5: ['Vishesh', 'Biswajeet', 'Kranti'],
        8: ['Vishesh', 'Biswajeet', 'Kranti'],
        10: ['Vishesh', 'Biswajeet', 'Kranti']
    },
    0.7: {
        1: ['Biswajeet', 'Vishesh', 'Kranti'],
        2: ['Vishesh', 'Biswajeet', 'Kranti'],
        3: ['Biswajeet', 'Vishesh', 'Kranti'],
        5: ['Vishesh', 'Biswajeet', 'Kranti'],
        8: ['Vishesh', 'Biswajeet', 'Kranti'],
        10: ['Biswajeet', 'Vishesh', 'Kranti']
    },
    0.9: {
        1: ['Vishesh', 'Biswajeet', 'Kranti'],
        2: ['Vishesh', 'Biswajeet', 'Kranti'],
        3: ['Vishesh', 'Biswajeet', 'Kranti'],
        5: ['Vishesh', 'Biswajeet', 'Kranti'],
        8: ['Vishesh', 'Biswajeet', 'Kranti'],
        10: ['Vishesh', 'Biswajeet', 'Kranti']
    },
    1.0: {
        1: ['Vishesh', 'Biswajeet'],
        2: ['Vishesh'],
        3: ['Biswajeet'],
        5: ['Vishesh', 'Biswajeet'],
        8: [],
        10: ['Vishesh', 'Biswajeet']
    }},
    'Sai':{
        0.5: {
            1: ['Biswajeet', 'Adhiraaj', 'Vishesh'],
            2: ['Biswajeet', 'Vishesh', 'Kranti'],
            3: ['Adhiraaj', 'Biswajeet', 'Kranti'],
            5: ['Biswajeet', 'Vishesh', 'Adhiraaj'],
            8: ['Biswajeet', 'Kranti', 'Vishesh'],
            10: ['Adhiraaj', 'Kranti', 'Biswajeet']
        },
        0.7: {
            1: ['Biswajeet', 'Adhiraaj', 'Vishesh'],
            2: ['Vishesh', 'Biswajeet', 'Adhiraaj'],
            3: ['Adhiraaj', 'Vishesh', 'Biswajeet'],
            5: ['Vishesh', 'Adhiraaj', 'Biswajeet'],
            8: ['Vishesh', 'Biswajeet', 'Adhiraaj'],
            10: ['Biswajeet', 'Kranti', 'Adhiraaj']
        },
        0.9: {
            1: ['Kranti', 'Adhiraaj', 'Biswajeet'],
            2: ['Adhiraaj', 'Vishesh', 'Biswajeet'],
            3: ['Adhiraaj', 'Biswajeet', 'Vishesh'],
            5: ['Biswajeet', 'Vishesh', 'Kranti'],
            8: ['Biswajeet', 'Vishesh', 'Kranti'],
            10: ['Adhiraaj', 'Kranti', 'Biswajeet']
        },
        1.0: {
            1: ['Biswajeet', 'Kranti'],
            2: ['Biswajeet'],
            3: ['Kranti'],
            5: ['Vishesh', 'Biswajeet'],
            8: [],
            10: ['Kranti', 'Biswajeet']
        }
}
}
# Plotting all recommendations
import matplotlib.pyplot as plt

# Names and their corresponding indices
names = ['Shrestha', 'Vishesh', 'Biswajeet', 'Priyanka', 'Poonam', 'Adhiraaj', 'Yash', 'Sachin', 'Vinayak', 'Kranti', 'Sai']
name_to_idx = {name: idx for idx, name in enumerate(names)}

# Thresholds and batch sizes
thresholds = [0.5, 0.7, 0.9, 1.0]
batch_sizes = [1, 2, 3, 5, 8, 10]

# Colors and markers for different thresholds
colors = {0.5: 'red', 0.7: 'blue', 0.9: 'green', 1.0: 'purple'}
markers = {0.5: 'o', 0.7: 's', 0.9: 'D', 1.0: 'x'}

# Plotting setup
fig, ax = plt.subplots(figsize=(12, 8))

# Plotting for each person
for person, recommendations_data in recommendations.items():
    for thr in thresholds:
        for batch_size in batch_sizes:
            recommended_nodes = recommendations_data[thr][batch_size]
            y_value = batch_size
            x_values = [name_to_idx[name] for name in recommended_nodes]
            ax.scatter(x_values, [y_value] * len(x_values), c=colors[thr], label=f'{person}, Threshold {thr}' if batch_size == 1 else "", marker=markers[thr], s=100)

# Customizing the plot
ax.set_title('Recommended Nodes for Multiple Persons')
ax.set_xlabel('Names')
ax.set_ylabel('Batch Size')
ax.set_xticks(range(len(names)))
ax.set_xticklabels(names, rotation=90)
ax.set_yticks(batch_sizes)
ax.legend(title='Recommendations', loc='upper right')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 261
#     259 for thr in thresholds:
#     260     for batch_size in batch_sizes:
# --> 261         recommended_nodes = recommendations_data[thr][batch_size]
#     262         y_value = batch_size
#     263         x_values = [name_to_idx[name] for name in recommended_nodes]
#
# KeyError: 0.5

# %%
import matplotlib.pyplot as plt

# Data organized by individual
individuals = {
    'Shrestha': {
        0.5: {
            1: ['Vishesh'],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: ['Vishesh'],
            8: ['Vishesh'],
            10: ['Vishesh']
        },
        0.7: {
            1: ['Vishesh'],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: ['Vishesh'],
            8: ['Vishesh'],
            10: ['Vishesh']
        },
        0.9: {
            1: ['Vishesh'],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: ['Vishesh'],
            8: ['Vishesh'],
            10: ['Vishesh']
        },
        1.0: {
            1: [],
            2: ['Vishesh'],
            3: ['Vishesh'],
            5: [],
            8: ['Vishesh'],
            10: ['Vishesh']
        }
    },
    'Vishesh':{ 
    0.5 :  {
    1 : ['biswajeet', 'vinayak', 'yash'],
    2 : ['shrestha', 'poonam', 'sachin'],
    3 : ['adhiraaj', 'shrestha', 'priyanka'],
    5 : ['biswajeet', 'shrestha', 'sai'],
    8 : ['shrestha', 'priyanka', 'vinayak'],
    10 : ['sachin', 'biswajeet', 'adhiraaj']},
    0.7 : {
    1 : ['shrestha', 'biswajeet', 'poonam'],
    2 : ['shrestha', 'yash', 'adhiraaj'],
    3 : ['priyanka', 'shrestha', 'poonam'],
    5 : ['shrestha', 'sai', 'biswajeet'],
    8 : ['shrestha', 'adhiraaj', 'priyanka'],
    10 : ['poonam', 'vinayak', 'sai']},
    0.9 : {
    1 : ['priyanka', 'biswajeet', 'sai'],
    2 : ['poonam', 'shrestha', 'vinayak'],
    3 : ['vinayak', 'sachin', 'priyanka'],
    8 : ['shrestha', 'priyanka', 'vinayak'],
    10 : ['sai', 'yash', 'adhiraaj']},
    1.0 : {
    1 : ['adhiraaj', 'poonam', 'vinayak'],
    2 : ['adhiraaj', 'shrestha', 'biswajeet'],
    3 : ['biswajeet', 'yash', 'sachin'],
    5 : ['poonam', 'yash', 'sai'],
    8 : ['sai', 'adhiraaj', 'shrestha'],
    10 : ['shrestha', 'adhiraaj', 'yash']
        }
    },
    'Biswajeet': {
        0.5: {
            1: ['Kranti', 'Vinayak', 'Sachin'],
            2: ['Kranti', 'Sachin', 'Yash'],
            3: ['Sai', 'Adhiraaj', 'Vishesh'],
            5: ['Priyanka', 'Poonam', 'Kranti'],
            8: ['Sachin', 'Adhiraaj', 'Vinayak'],
            10: ['Poonam', 'Priyanka', 'Sachin']
        },
        0.7: {
            1: ['Yash', 'Vishesh', 'Sai'],
            2: ['Adhiraaj', 'Sachin', 'Yash'],
            3: ['Sai', 'Vishesh', 'Adhiraaj'],
            5: ['Sai', 'Priyanka', 'Kranti'],
            8: ['Vishesh', 'Sachin', 'Sai'],
            10: ['Sai', 'Poonam', 'Priyanka']
        },
        0.9: {
            1: ['Sachin', 'Vinayak', 'Adhiraaj'],
            2: ['Sai', 'Vinayak', 'Poonam'],
            3: ['Sai', 'Priyanka', 'Poonam'],
            5: ['Sai', 'Adhiraaj', 'Sachin'],
            8: ['Sachin', 'Sai', 'Kranti'],
            10: ['Kranti', 'Vinayak', 'Yash']
        },
        1.0: {
            1: ['Sai', 'Sachin', 'Yash'],
            2: ['Kranti', 'Sachin', 'Adhiraaj'],
            3: ['Poonam', 'Vinayak', 'Priyanka'],
            5: ['Sai', 'Yash', 'Priyanka'],
            8: ['Sai', 'Vinayak', 'Vishesh'],
            10: ['Vinayak', 'Sai', 'Sachin']
        }
    },
    'Priyanka': {
        0.5: {
            1: ['Sachin', 'Vishesh', 'Yash'],
            2: ['Adhiraaj', 'Biswajeet', 'Yash'],
            3: ['Adhiraaj', 'Biswajeet', 'Yash'],
            5: ['Sachin', 'Vishesh', 'Biswajeet'],
            8: ['Poonam', 'Biswajeet', 'Adhiraaj'],
            10: ['Sachin', 'Adhiraaj', 'Biswajeet']
        },
        0.7: {
            1: ['Adhiraaj', 'Yash', 'Vishesh'],
            2: ['Sachin', 'Yash', 'Biswajeet'],
            3: ['Vishesh', 'Biswajeet', 'Sachin'],
            5: ['Vishesh', 'Biswajeet', 'Sachin'],
            8: ['Yash', 'Biswajeet', 'Poonam'],
            10: ['Adhiraaj', 'Vishesh', 'Biswajeet']
        },
        0.9: {
            1: ['Yash', 'Sachin', 'Poonam'],
            2: ['Yash', 'Sachin', 'Adhiraaj'],
            3: ['Adhiraaj', 'Sachin', 'Yash'],
            5: ['Biswajeet', 'Poonam', 'Yash'],
            8: ['Adhiraaj', 'Yash', 'Poonam'],
            10: ['Biswajeet', 'Sachin', 'Adhiraaj']
        },
        1.0: {
            1: ['Vishesh', 'Sachin', 'Adhiraaj'],
            2: ['Biswajeet', 'Vishesh', 'Sachin'],
            3: ['Biswajeet', 'Yash', 'Sachin'],
            5: ['Sachin', 'Poonam', 'Adhiraaj'],
            8: ['Yash', 'Poonam', 'Sachin'],
            10: ['Biswajeet', 'Poonam', 'Yash']
        }
    },
    'Poonam': {
        0.5: {
            1: ['Adhiraaj', 'Yash', 'Biswajeet'],
            2: ['Adhiraaj', 'Sachin', 'Biswajeet'],
            3: ['Adhiraaj', 'Priyanka', 'Sachin'],
            5: ['Vishesh', 'Yash', 'Priyanka'],
            8: ['Adhiraaj', 'Priyanka', 'Vishesh'],
            10: ['Vishesh', 'Biswajeet', 'Priyanka']
        },
        0.7: {
            1: ['Adhiraaj', 'Sachin', 'Biswajeet'],
            2: ['Vishesh', 'Biswajeet', 'Adhiraaj'],
            3: ['Priyanka', 'Vishesh', 'Yash'],
            5: ['Priyanka', 'Sachin', 'Yash'],
            8: ['Priyanka', 'Biswajeet', 'Sachin'],
            10: ['Adhiraaj', 'Priyanka', 'Sachin']
        },
        0.9: {
            1: ['Sachin',
# Out:
#   Cell In[26], line 155
#     1: ['Sachin',
#                  ^
# SyntaxError: incomplete input

# %%
import matplotlib.pyplot as plt

# Names and their corresponding indices
names = ['Shrestha', 'Vishesh', 'Biswajeet', 'Priyanka', 'Poonam', 'Adhiraaj', 'Yash', 'Sachin', 'Vinayak', 'Kranti', 'Sai']
name_to_idx = {name: idx for idx, name in enumerate(names)}

# Thresholds and batch sizes
thresholds = [0.5, 0.7, 0.9, 1.0]
batch_sizes = [1, 2, 3, 5, 8, 10]

# Colors and markers for different thresholds
colors = {0.5: 'red', 0.7: 'blue', 0.9: 'green', 1.0: 'purple'}
markers = {0.5: 'o', 0.7: 's', 0.9: 'D', 1.0: 'x'}

# Plotting setup
fig, ax = plt.subplots(figsize=(12, 8))

# Plotting for each person
for person, recommendations_data in individuals.items():
    for thr in thresholds:
        for batch_size in batch_sizes:
            if batch_size in recommendations_data[thr]:
                recommended_nodes = recommendations_data[thr][batch_size]
                y_value = batch_size
                x_values = [name_to_idx[name] for name in recommended_nodes]
                ax.scatter(x_values, [y_value] * len(x_values), c=colors[thr], 
                           label=f'{person}, Threshold {thr}' if batch_size == 1 else "", marker=markers[thr], s=100)

# Customizing the plot
ax.set_title('Recommended Nodes for Multiple Persons')
ax.set_xlabel('Names')
ax.set_ylabel('Batch Size')
ax.set_xticks(range(len(names)))
ax.set_xticklabels(names, rotation=90)
ax.set_yticks(batch_sizes)
ax.legend(title='Recommendations', loc='upper right', bbox_to_anchor=(1.2, 1))

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 28
#      26             y_value = batch_size
#      27             x_values = [name_to_idx[name]] * len(recommended_nodes)
# ---> 28             y_values = [name_to_idx[rec] for rec in recommended_nodes]
#      29             ax.scatter(x_values, y_values, c=colors[thr], label=f'{name}, Threshold {thr}' if batch_size == 1 else "", marker=markers[thr], s=100)
#      31 # Customizing the plot
#
# Cell In[19], line 28, in <listcomp>(.0)
#      26             y_value = batch_size
#      27             x_values = [name_to_idx[name]] * len(recommended_nodes)
# ---> 28             y_values = [name_to_idx[rec] for rec in recommended_nodes]
#      29             ax.scatter(x_values, y_values, c=colors[thr], label=f'{name}, Threshold {thr}' if batch_size == 1 else "", marker=markers[thr], s=100)
# ...
